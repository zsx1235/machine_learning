# %% [markdown]
# # 1.导包

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from sklearn.preprocessing import MinMaxScaler
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False #用来正常显示负号
import warnings
import torch.optim as optim
warnings.filterwarnings("ignore", category=pd.errors.SettingWithCopyWarning)

# %% [markdown]
# # 2.读取数据

# %%
# 加载数据
train_data = pd.read_csv("data/train_data.csv")
test_data = pd.read_csv("data/test_data.csv")
train_data = train_data.iloc[:-3] # 删除最后三行NaN值

# %% [markdown]
# # 3.数据预处理

# %%
# 数值特征
numerical_features_to_scale = ['casual', 'registered']  # 需要归一化的特征
numerical_features_no_scale = ['temp', 'atemp', 'hum', 'windspeed']  # 不需要归一化的特征
target_column = 'cnt'

# 数据预处理
train_data.fillna(0, inplace=True)
test_data.fillna(0, inplace=True)

# 初始化归一化器
scaler_cnt = MinMaxScaler()
scaler_features = MinMaxScaler()

# 归一化目标变量
scaler_cnt.fit(train_data[[target_column]])
train_data[target_column] = scaler_cnt.transform(train_data[[target_column]])
test_data[target_column] = scaler_cnt.transform(test_data[[target_column]])

# 归一化特征
scaler_features.fit(train_data[numerical_features_to_scale])
train_data[numerical_features_to_scale] = scaler_features.transform(train_data[numerical_features_to_scale])
test_data[numerical_features_to_scale] = scaler_features.transform(test_data[numerical_features_to_scale])

# %%
# 时间特征处理
def preprocess_time_features(data):
    data['hour_sin'] = np.sin(2 * np.pi * data['hr'] / 24.0)
    data['hour_cos'] = np.cos(2 * np.pi * data['hr'] / 24.0)
    data['weekday_sin'] = np.sin(2 * np.pi * data['weekday'] / 7.0)
    data['weekday_cos'] = np.cos(2 * np.pi * data['weekday'] / 7.0)
    data['season_sin'] = np.sin(2 * np.pi * data['season'] / 4.0)
    data['season_cos'] = np.cos(2 * np.pi * data['season'] / 4.0)
    data['month_sin'] = np.sin(2 * np.pi * data['mnth'] / 12.0)
    data['month_cos'] = np.cos(2 * np.pi * data['mnth'] / 12.0)
    return data
train_data = preprocess_time_features(train_data)
test_data = preprocess_time_features(test_data)

# %% [markdown]
# # 4.特征提取

# %%
# 特征列表
features = [
    'hour_sin', 'hour_cos',  # 小时周期
    'weekday_sin', 'weekday_cos',  # 周周期
    'season_sin', 'season_cos',  # 季节周期
    'month_sin', 'month_cos',  # 月份周期
    'yr', 'holiday', 'workingday', 'weathersit',  # 分类特征
    'temp', 'atemp', 'hum', 'windspeed',  # 数值特征
    'casual', 'registered'  # 归一化特征
]

X_train = train_data[features]
X_test = test_data[features]

y_train = train_data[target_column]
y_test = test_data[target_column]

# %% [markdown]
# # 5.划分数据集

# %%
def create_dataset(X, y, seq_len=96, output_len=240, step=1):
    features, targets = [], []
    for i in range(0, len(X) - seq_len - output_len + 1, step):
        features.append(X.iloc[i:i+seq_len].values)  # 过去的96小时数据
        targets.append(y.iloc[i+seq_len:i+seq_len+output_len].values)  # 未来的240小时数据
    return np.array(features), np.array(targets)

# 修改后的数据集生成
train_dataset, train_labels = create_dataset(X_train, y_train, seq_len=96, output_len=240)
test_dataset, test_labels = create_dataset(X_test, y_test, seq_len=96, output_len=240)

# %%
# 自定义数据集
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.float32)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]
        
train_loader = DataLoader(CustomDataset(train_dataset, train_labels), batch_size=64, shuffle=True)
test_loader = DataLoader(CustomDataset(test_dataset, test_labels), batch_size=64, shuffle=False)

# %% [markdown]
# # 6. 模型架构

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size=256, num_layers=3, output_size=240, dropout=0.3):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size=input_size, hidden_size=hidden_size, num_layers=num_layers,
                            batch_first=True, dropout=dropout)
        self.fc = nn.Linear(hidden_size, output_size)  # 修改输出为240小时

    def forward(self, x):
        x, _ = self.lstm(x)
        x = x[:, -1, :]  # 使用最后一个时间步的输出
        x = self.fc(x)   # 输出层
        return x

# %% [markdown]
# # 7.训练并保存最佳模型

# %%
# 定义多次实验函数
def run_experiments(model_class, train_loader, test_loader, epochs=50, num_experiments=5):
    """
    运行多次实验，并保存每次实验的最佳模型。

    :param model_class: 模型类
    :param train_loader: 训练数据加载器
    :param test_loader: 测试数据加载器
    :param epochs: 每次实验的训练轮数
    :param num_experiments: 实验次数
    """
    test_losses = []  # 保存每次实验的最佳 Test Loss

    for i in range(num_experiments):
        print(f"Starting Experiment {i + 1}/{num_experiments}")

        # 初始化模型和优化器
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        input_size = train_dataset.shape[2]
        model = model_class(input_size=input_size, hidden_size=256, num_layers=3, output_size=240, dropout=0.3).to(device)
        criterion = nn.MSELoss()
        optimizer = optim.AdamW(model.parameters(), lr=0.001, weight_decay=1e-4)
        scheduler = optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.01, steps_per_epoch=len(train_loader), epochs=epochs)

        best_loss = float('inf')  # 当前实验的最佳 Test Loss

        # 训练模型
        for epoch in range(epochs):
            model.train()
            train_loss = 0.0
            for batch_X, batch_y in train_loader:
                batch_X, batch_y = batch_X.to(device), batch_y.to(device)
                optimizer.zero_grad()
                outputs = model(batch_X)
                loss = criterion(outputs, batch_y)
                loss.backward()
                optimizer.step()
                train_loss += loss.item()
            train_loss /= len(train_loader)

            # 验证模型
            model.eval()
            test_loss = 0.0
            with torch.no_grad():
                for batch_X, batch_y in test_loader:
                    batch_X, batch_y = batch_X.to(device), batch_y.to(device)
                    outputs = model(batch_X)
                    loss = criterion(outputs, batch_y)
                    test_loss += loss.item()
            test_loss /= len(test_loader)

            scheduler.step()

            print(f"Experiment {i + 1}, Epoch {epoch+1}/{epochs}, Train Loss: {train_loss:.6f}, Test Loss: {test_loss:.6f}")

            # 保存最佳模型
            if test_loss < best_loss:
                best_loss = test_loss
                torch.save(model.state_dict(), f"model/lstm_long_best_model_{i + 1}.pth")
                print(f"Experiment {i + 1}: Best model saved with Test Loss: {test_loss:.6f}")

        test_losses.append(best_loss)

    # 打印实验结果
    avg_loss = sum(test_losses) / num_experiments
    print(f"\nAll Experiments Completed!")
    print(f"Test Losses: {test_losses}")
    print(f"Average Test Loss: {avg_loss:.6f}")
    print(f"Standard Deviation of Test Loss: {np.std(test_losses):.6f}")

# 调用函数运行实验
run_experiments(
    model_class=LSTMModel,  # 确保传递的是模型类
    train_loader=train_loader,
    test_loader=test_loader,
    epochs=30,
    num_experiments=5
)
# Out:
# Starting Experiment 1/5
# Experiment 1, Epoch 1/30, Train Loss: 0.022448, Test Loss: 0.028217
# Experiment 1: Best model saved with Test Loss: 0.028217
# Experiment 1, Epoch 2/30, Train Loss: 0.012010, Test Loss: 0.038282
# Experiment 1, Epoch 3/30, Train Loss: 0.010565, Test Loss: 0.031620
# Experiment 1, Epoch 4/30, Train Loss: 0.008291, Test Loss: 0.029304
# Experiment 1, Epoch 5/30, Train Loss: 0.007371, Test Loss: 0.025666
# Experiment 1: Best model saved with Test Loss: 0.025666
# Experiment 1, Epoch 6/30, Train Loss: 0.006914, Test Loss: 0.021720
# Experiment 1: Best model saved with Test Loss: 0.021720
# Experiment 1, Epoch 7/30, Train Loss: 0.006501, Test Loss: 0.021211
# Experiment 1: Best model saved with Test Loss: 0.021211
# Experiment 1, Epoch 8/30, Train Loss: 0.006208, Test Loss: 0.019743
# Experiment 1: Best model saved with Test Loss: 0.019743
# Experiment 1, Epoch 9/30, Train Loss: 0.005909, Test Loss: 0.019761
# Experiment 1, Epoch 10/30, Train Loss: 0.005703, Test Loss: 0.020559
# Experiment 1, Epoch 11/30, Train Loss: 0.005445, Test Loss: 0.021266
# Experiment 1, Epoch 12/30, Train Loss: 0.005499, Test Loss: 0.026107
# Experiment 1, Epoch 13/30, Train Loss: 0.005239, Test Loss: 0.022929
# Experiment 1, Epoch 14/30, Train Loss: 0.004946, Test Loss: 0.022142
# Experiment 1, Epoch 15/30, Train Loss: 0.004796, Test Loss: 0.024438
# Experiment 1, Epoch 16/30, Train Loss: 0.004649, Test Loss: 0.024223
# Experiment 1, Epoch 17/30, Train Loss: 0.004368, Test Loss: 0.022451
# Experiment 1, Epoch 18/30, Train Loss: 0.004186, Test Loss: 0.023152
# Experiment 1, Epoch 19/30, Train Loss: 0.004013, Test Loss: 0.024227
# Experiment 1, Epoch 20/30, Train Loss: 0.003874, Test Loss: 0.022876
# Experiment 1, Epoch 21/30, Train Loss: 0.003737, Test Loss: 0.021771
# Experiment 1, Epoch 22/30, Train Loss: 0.003630, Test Loss: 0.023241
# Experiment 1, Epoch 23/30, Train Loss: 0.003417, Test Loss: 0.023683
# Experiment 1, Epoch 24/30, Train Loss: 0.003366, Test Loss: 0.021781
# Experiment 1, Epoch 25/30, Train Loss: 0.003382, Test Loss: 0.023974
# Experiment 1, Epoch 26/30, Train Loss: 0.003204, Test Loss: 0.022060
# Experiment 1, Epoch 27/30, Train Loss: 0.003104, Test Loss: 0.022922
# Experiment 1, Epoch 28/30, Train Loss: 0.002908, Test Loss: 0.024533
# Experiment 1, Epoch 29/30, Train Loss: 0.002792, Test Loss: 0.022151
# Experiment 1, Epoch 30/30, Train Loss: 0.002658, Test Loss: 0.023041
# Starting Experiment 2/5
# Experiment 2, Epoch 1/30, Train Loss: 0.021487, Test Loss: 0.031591
# Experiment 2: Best model saved with Test Loss: 0.031591
# Experiment 2, Epoch 2/30, Train Loss: 0.011976, Test Loss: 0.043562
# Experiment 2, Epoch 3/30, Train Loss: 0.010253, Test Loss: 0.028102
# Experiment 2: Best model saved with Test Loss: 0.028102
# Experiment 2, Epoch 4/30, Train Loss: 0.008008, Test Loss: 0.027294
# Experiment 2: Best model saved with Test Loss: 0.027294
# Experiment 2, Epoch 5/30, Train Loss: 0.007234, Test Loss: 0.023796
# Experiment 2: Best model saved with Test Loss: 0.023796
# Experiment 3, Epoch 8/30, Train Loss: 0.006064, Test Loss: 0.024732
# Experiment 3, Epoch 9/30, Train Loss: 0.005792, Test Loss: 0.024073
# Experiment 3, Epoch 10/30, Train Loss: 0.005617, Test Loss: 0.024872
# Experiment 3, Epoch 11/30, Train Loss: 0.005384, Test Loss: 0.026354
# Experiment 3, Epoch 12/30, Train Loss: 0.005253, Test Loss: 0.028131
# Experiment 3, Epoch 13/30, Train Loss: 0.005050, Test Loss: 0.027304
# Experiment 3, Epoch 14/30, Train Loss: 0.005028, Test Loss: 0.029181
# Experiment 3, Epoch 15/30, Train Loss: 0.004753, Test Loss: 0.025468
# Experiment 3, Epoch 16/30, Train Loss: 0.004532, Test Loss: 0.027186
# Experiment 3, Epoch 17/30, Train Loss: 0.004687, Test Loss: 0.023628
# Experiment 3, Epoch 18/30, Train Loss: 0.004889, Test Loss: 0.028906
# Experiment 3, Epoch 19/30, Train Loss: 0.004487, Test Loss: 0.031458
# Experiment 3, Epoch 20/30, Train Loss: 0.004177, Test Loss: 0.031863
# Experiment 3, Epoch 21/30, Train Loss: 0.004001, Test Loss: 0.034435
# Experiment 3, Epoch 22/30, Train Loss: 0.003914, Test Loss: 0.028977
# Experiment 3, Epoch 23/30, Train Loss: 0.003647, Test Loss: 0.030084
# Experiment 3, Epoch 24/30, Train Loss: 0.003619, Test Loss: 0.027752
# Experiment 3, Epoch 25/30, Train Loss: 0.003389, Test Loss: 0.029075
# Experiment 3, Epoch 26/30, Train Loss: 0.003272, Test Loss: 0.028749
# Experiment 3, Epoch 27/30, Train Loss: 0.003173, Test Loss: 0.030047
# Experiment 3, Epoch 28/30, Train Loss: 0.003063, Test Loss: 0.027871
# Experiment 3, Epoch 29/30, Train Loss: 0.003010, Test Loss: 0.025828
# Experiment 3, Epoch 30/30, Train Loss: 0.003034, Test Loss: 0.027376
# Starting Experiment 4/5
# Experiment 4, Epoch 1/30, Train Loss: 0.022857, Test Loss: 0.026471
# Experiment 4: Best model saved with Test Loss: 0.026471
# Experiment 4, Epoch 2/30, Train Loss: 0.012074, Test Loss: 0.033228
# Experiment 4, Epoch 3/30, Train Loss: 0.010540, Test Loss: 0.029089
# Experiment 4, Epoch 4/30, Train Loss: 0.008229, Test Loss: 0.026983
# Experiment 4, Epoch 5/30, Train Loss: 0.007387, Test Loss: 0.024028
# Experiment 4: Best model saved with Test Loss: 0.024028
# Experiment 4, Epoch 6/30, Train Loss: 0.006899, Test Loss: 0.023480
# Experiment 4: Best model saved with Test Loss: 0.023480
# Experiment 4, Epoch 7/30, Train Loss: 0.006460, Test Loss: 0.022073
# Experiment 4: Best model saved with Test Loss: 0.022073
# Experiment 4, Epoch 8/30, Train Loss: 0.006133, Test Loss: 0.023667
# Experiment 4, Epoch 9/30, Train Loss: 0.005774, Test Loss: 0.020625
# Experiment 4: Best model saved with Test Loss: 0.020625
# Experiment 5: Best model saved with Test Loss: 0.021685
# Experiment 5, Epoch 13/30, Train Loss: 0.005278, Test Loss: 0.025041
# Experiment 5, Epoch 14/30, Train Loss: 0.005012, Test Loss: 0.025136
# Experiment 5, Epoch 15/30, Train Loss: 0.004775, Test Loss: 0.026547
# Experiment 5, Epoch 16/30, Train Loss: 0.004917, Test Loss: 0.023283
# Experiment 5, Epoch 17/30, Train Loss: 0.004849, Test Loss: 0.025748
# Experiment 5, Epoch 18/30, Train Loss: 0.004560, Test Loss: 0.025322
# Experiment 5, Epoch 19/30, Train Loss: 0.004186, Test Loss: 0.028907
# Experiment 5, Epoch 20/30, Train Loss: 0.004140, Test Loss: 0.026639
# Experiment 5, Epoch 21/30, Train Loss: 0.003939, Test Loss: 0.026889
# Experiment 5, Epoch 22/30, Train Loss: 0.003800, Test Loss: 0.028233
# Experiment 5, Epoch 23/30, Train Loss: 0.003732, Test Loss: 0.025955
# Experiment 5, Epoch 24/30, Train Loss: 0.003453, Test Loss: 0.027152
# Experiment 5, Epoch 25/30, Train Loss: 0.003433, Test Loss: 0.028710
# Experiment 5, Epoch 26/30, Train Loss: 0.003198, Test Loss: 0.025996
# Experiment 5, Epoch 27/30, Train Loss: 0.003079, Test Loss: 0.026902
# Experiment 5, Epoch 28/30, Train Loss: 0.003095, Test Loss: 0.025722
# Experiment 5, Epoch 29/30, Train Loss: 0.002876, Test Loss: 0.027044
# Experiment 5, Epoch 30/30, Train Loss: 0.002744, Test Loss: 0.028400
#
# All Experiments Completed!
# Test Losses: [0.01974266414241544, 0.020279135137539487, 0.023020939532153565, 0.020625204987952422, 0.021684584512921243]
# Average Test Loss: 0.021071
# Standard Deviation of Test Loss: 0.001164

# %% [markdown]
# # 8. 通过模型进行预测

# %%
def predict_average(models, test_loader, model_class, input_size, device):
    """
    使用多个模型进行预测并求平均值。

    :param models: 模型文件路径列表
    :param test_loader: 测试数据加载器
    :param model_class: 模型类
    :param input_size: 输入数据的特征数
    :param device: 使用的设备 (CPU 或 GPU)
    :return: 平均预测结果和真实值
    """
    all_predictions = []

    # 遍历所有模型，逐个加载并进行预测
    for model_path in models:
        print(f"Loading model: {model_path}")
        # 初始化模型
        model = model_class(input_size=input_size, hidden_size=256, num_layers=3, output_size=240, dropout=0.3).to(device)
        model.load_state_dict(torch.load(model_path))  # 加载模型权重
        model.eval()

        predictions = []
        actuals = []
        with torch.no_grad():
            for batch_X, batch_y in test_loader:
                batch_X = batch_X.to(device)
                outputs = model(batch_X).cpu().numpy()  # 获取预测值
                predictions.extend(outputs)
                actuals.extend(batch_y.cpu().numpy())

        all_predictions.append(np.array(predictions))  # 将预测结果存储

    # 将所有预测结果求平均
    average_predictions = np.mean(all_predictions, axis=0)  # 逐样本求平均
    return average_predictions, np.array(actuals)

# 定义模型文件路径列表
models = [f"model/lstm_long_best_model_{i+1}.pth" for i in range(5)]

# 获取输入大小
input_size = train_loader.dataset[0][0].shape[1]  # 假设输入数据是 (batch_size, seq_len, input_size)

# 调用函数进行预测
average_predictions, actuals = predict_average(
    models=models,
    test_loader=test_loader,
    model_class=LSTMModel,  # 提供模型类
    input_size=input_size,
    device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
)

# 打印结果
print("Predictions shape:", average_predictions.shape)
print("Actuals shape:", actuals.shape)
# Out:
# Loading model: model/lstm_long_best_model_1.pth
# /tmp/ipykernel_7167/1282422339.py:19: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))  # 加载模型权重
# Loading model: model/lstm_long_best_model_2.pth
# Loading model: model/lstm_long_best_model_3.pth
# Loading model: model/lstm_long_best_model_4.pth
# Loading model: model/lstm_long_best_model_5.pth
# Predictions shape: (1825, 240)
# Actuals shape: (1825, 240)

# %% [markdown]
# # 9.计算MSE和MAE

# %%
# 反归一化预测和实际值
average_predictions = scaler_cnt.inverse_transform(average_predictions)
actuals = scaler_cnt.inverse_transform(actuals)

# 每个样本的 MSE 和 MAE
mse_per_sample = np.mean((average_predictions - actuals) ** 2, axis=1)  # 每个样本的 MSE
mae_per_sample = np.mean(np.abs(average_predictions - actuals), axis=1)  # 每个样本的 MAE

# 计算均值和标准差
mse_mean = np.mean(mse_per_sample)
mse_std = np.std(mse_per_sample)
mae_mean = np.mean(mae_per_sample)
mae_std = np.std(mae_per_sample)

# 输出结果
print(f"Mean Squared Error (MSE): {mse_mean:.6f} ± {mse_std:.6f}")
print(f"Mean Absolute Error (MAE): {mae_mean:.6f} ± {mae_std:.6f}")
# Out:
# Mean Squared Error (MSE): 18967.087891 ± 21728.085938
# Mean Absolute Error (MAE): 85.546440 ± 49.260612

# %% [markdown]
# # 10.绘图

# %%
# 构造完整数据：过去96小时的真实值和未来240小时的预测值
import logging
logging.getLogger('matplotlib').setLevel(logging.ERROR)
past_96_hours = scaler_cnt.inverse_transform(y_train.iloc[-96:].values.reshape(-1, 1)).flatten()
future_240_hours_actuals = actuals[0]  # 真实值
future_240_hours_predictions = average_predictions[0]  # 预测值

# 绘制图表
plt.figure(figsize=(16, 8))  # 调整图表大小

# 绘制真实值曲线（过去96小时和未来240小时）
plt.plot(
    range(336),  # 96 + 240 = 336小时
    np.concatenate((past_96_hours, future_240_hours_actuals)), 
    label="Ground Truth", color="#1E88E5", linewidth=2  # 深蓝色
)

# 绘制预测值曲线（未来240小时）
plt.plot(
    range(96, 336),  # 从96到336（仅预测部分）
    future_240_hours_predictions, 
    label="Prediction", color="#E53935", linestyle="--", linewidth=2  # 深红色
)

# 添加图例和标题
plt.legend(fontsize=12, loc="upper right")  # 图例在右上角
plt.title("LSTM-Based Prediction vs Ground Truth (240 Future Hours)", fontsize=16, fontweight="bold")
plt.xlabel("Hour", fontsize=14)
plt.ylabel("Bike Count", fontsize=14)

# 调整坐标轴样式
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(color="gray", linestyle="--", linewidth=0.5, alpha=0.7)

# 保存并展示图像
plt.savefig("bike_rental_predictions_lstm240.png", dpi=300, bbox_inches='tight')
plt.show()
